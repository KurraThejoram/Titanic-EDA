# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %%
from subprocess import check_output

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
df_train = pd.read_csv("C://Users/user/Downloads/data science/data sets/titanic/train.csv")

# %%
df_test = pd.read_csv("c://Users/user/Downloads/data science/data sets/titanic/test.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# # Of all passengers in df_train, how many survived, how many died ?

# %%
sns.countplot(x='Survived',data=df_train)

# %%
print(df_train.Survived.sum()/df_train.Survived.count())
# Out:
# 0.3838383838383838

# %%
#0 means dead 1 means survived so sum()= addition of all survived ,count()=total number sum()/count()=survived%

# %%
df_train.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=df_train);

# %%
print("% of women survived:",df_train[df_train.Sex == 'female'].Survived.sum()/
      df_train[df_train.Sex == 'female'].Survived.count())
# Out:
# % of women survived: 0.7420382165605095

# %%
print("% of men survived:",df_train[df_train.Sex == 'male'].Survived.sum()/
      df_train[df_train.Sex == 'male'].Survived.count())
# Out:
# % of men survived: 0.18890814558058924

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
df_train['Survived'][df_train['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df_train['Survived'][df_train['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Survived(male)')
ax[1].set_title('Survived(female)')
# Out:
# Text(0.5, 1.0, 'Survived(female)')

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow0_col1 {
#             background-color:  #ffce00;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow0_col2 {
#             background-color:  #fff400;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow1_col0 {
#             background-color:  #fff600;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow1_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow1_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c95b5880_6c16_11ea_9bbf_5413797ca51crow2_col0 {
#             background-color:  #ff6000;
#             color:  #000000;
# ...

# %%
print("% of survivals in")
print("Pclass 1:",df_train.Survived[df_train.Pclass == 1].sum()/df_train.Survived[df_train.Pclass == 1].count())
print("Pclass 2:",df_train.Survived[df_train.Pclass == 2].sum()/df_train.Survived[df_train.Pclass == 2].count())
print("Pclass 3:",df_train.Survived[df_train.Pclass == 3].sum()/df_train.Survived[df_train.Pclass == 3].count())
# Out:
# % of survivals in
# Pclass 1: 0.6296296296296297
# Pclass 2: 0.47282608695652173
# Pclass 3: 0.24236252545824846

# %%
sns.catplot('Pclass','Survived',kind='point',data=df_train)

# %%
#Passenger Class and Sex :

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow0_col2 {
#             background-color:  #fff100;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow1_col0 {
#             background-color:  #ff9600;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow1_col1 {
#             background-color:  #ffa300;
#             color:  #000000;
#         }    #T_c9fe72ca_6c16_11ea_8cef_5413797ca51crow1_col2 {
#             background-color:  #fff100;
#             color:  #000000;
# ...

# %%
sns.catplot('Pclass','Survived',hue='Sex',kind='point',data=df_train)

# %%
sns.catplot(x='Sex', col='Embarked', kind='count', data=df_train);

# %%
sns.catplot('Embarked','Survived', kind='point', data=df_train);

# %%
sns.catplot('Embarked','Survived', hue= 'Sex', kind='point', data=df_train);

# %%
sns.catplot('Embarked','Survived', col='Pclass', hue= 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Survived], [df_train.Sex, df_train.Pclass, df_train.Embarked], margins=True
             ).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col5 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_b094972e_6c17_11ea_9a21_5413797ca51crow0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
import numpy as np

# %%
for df in [df_train,df_test]:
    df['Age_bin']=np.nan
    for i in range(8,0,-1):
        df.loc[df['Age'] <= i*10, 'Age_bin']=i

# %%
print(df_train[['Age' , 'Age_bin']].head(10))
# Out:
#     Age  Age_bin
# 0  22.0      3.0
# 1  38.0      4.0
# 2  26.0      3.0
# 3  35.0      4.0
# 4  35.0      4.0
# 5   NaN      NaN
# 6  54.0      6.0
# 7   2.0      1.0
# 8  27.0      3.0
# 9  14.0      2.0

# %%
sns.catplot('Age_bin','Survived',hue='Sex',kind='point',data=df_train);

# %%
sns.catplot('Age_bin','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Age_bin, df_train.Pclass],
            margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col0 {
#             background-color:  #ffaa00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col2 {
#             background-color:  #ffea00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col5 {
#             background-color:  #ffee00;
#             color:  #000000;
#         }    #T_ebff7a24_6c1a_11ea_b9db_5413797ca51crow0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
sns.catplot('SibSp','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.SibSp, df_train.Pclass], 
            margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col5 {
#             background-color:  #ffd900;
#             color:  #000000;
#         }    #T_db41e0e8_6c1a_11ea_8508_5413797ca51crow0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
sns.catplot('Parch','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Parch, df_train.Pclass], 
            margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col5 {
#             background-color:  #ffe400;
#             color:  #000000;
#         }    #T_d832010c_6c1a_11ea_8156_5413797ca51crow0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
sns.distplot(df_train['Fare']);

# %%
for df in [df_train, df_test]:
    df['Fare_bin']=np.nan
    for i in range(12,0,-1):
        df.loc[ df['Fare'] <= i*50, 'Fare_bin'] = i

# %%
sns.catplot('Fare_bin','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Fare_bin, df_train.Pclass],
            margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col2 {
#             background-color:  #fff000;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col5 {
#             background-color:  #ffc900;
#             color:  #000000;
#         }    #T_47701f70_6c27_11ea_8084_5413797ca51crow0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %% [markdown]
# # Part 2: Data wrangling¶

# %%
df_train_ml=df_train.copy()

# %%
df_test_ml=df_test.copy('')

# %%
df_train_ml=pd.get_dummies(df_train_ml, columns=['Sex','Embarked','Pclass'], drop_first=True)
df_train_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)
df_train_ml.dropna(inplace=True)

# %%
df_train_ml.head(10)
# Out:
#     Survived   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0          0  22.0      1      0   7.2500         1           0           1
# 1          1  38.0      1      0  71.2833         0           0           0
# 2          1  26.0      0      0   7.9250         0           0           1
# 3          1  35.0      1      0  53.1000         0           0           1
# 4          0  35.0      0      0   8.0500         1           0           1
# 6          0  54.0      0      0  51.8625         1           0           1
# 7          0   2.0      3      1  21.0750         1           0           1
# 8          1  27.0      0      2  11.1333         0           0           1
# 9          1  14.0      1      0  30.0708         0           0           0
# 10         1   4.0      1      1  16.7000         0           0           1
#
#     Pclass_2  Pclass_3
# 0          0         1
# 1          0         0
# 2          0         1
# 3          0         0
# ...

# %%
df_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 10 columns):
# Survived      714 non-null int64
# Age           714 non-null float64
# SibSp         714 non-null int64
# Parch         714 non-null int64
# Fare          714 non-null float64
# Sex_male      714 non-null uint8
# Embarked_Q    714 non-null uint8
# Embarked_S    714 non-null uint8
# Pclass_2      714 non-null uint8
# Pclass_3      714 non-null uint8
# dtypes: float64(2), int64(3), uint8(5)
# memory usage: 37.0 KB

# %%
df_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# Age           332 non-null float64
# SibSp         418 non-null int64
# Parch         418 non-null int64
# Fare          417 non-null float64
# Sex_male      418 non-null uint8
# Embarked_Q    418 non-null uint8
# Embarked_S    418 non-null uint8
# Pclass_2      418 non-null uint8
# Pclass_3      418 non-null uint8
# dtypes: float64(2), int64(2), uint8(5)
# memory usage: 15.2 KB

# %%
df_test_ml.head(10)
# Out:
#     Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  Pclass_2  \
# 0  34.5      0      0   7.8292         1           1           0         0
# 1  47.0      1      0   7.0000         0           0           1         0
# 2  62.0      0      0   9.6875         1           1           0         1
# 3  27.0      0      0   8.6625         1           0           1         0
# 4  22.0      1      1  12.2875         0           0           1         0
# 5  14.0      0      0   9.2250         1           0           1         0
# 6  30.0      0      0   7.6292         0           1           0         0
# 7  26.0      1      1  29.0000         1           0           1         1
# 8  18.0      0      0   7.2292         0           0           0         0
# 9  21.0      2      0  24.1500         1           0           1         0
#
#    Pclass_3
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
# 5         1
# 6         1
# 7         0
# 8         1
# ...

# %%
corr=df_train_ml.corr()
f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=2.5 , fmt = '.2f',ax=ax)
plt.show()
